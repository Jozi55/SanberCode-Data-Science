# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here
fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x,cos,linestyle='solid',color='#fc0303', label='Cosx')
ax.plot(x,cos3,linestyle='--',color='#03fc5a', label='3 Cosx')
ax.plot(x,sin,linestyle='-.',color='#1c03fc', label='Sin(X-90)')
ax.plot(x,sin2,marker='x',linestyle=' ',color='#fcf403', label='2Sinx')
ax.set_xlabel('X Label Axis')
ax.set_ylabel('Y Label Axis')
ax.set_title('Grapfik Cos Sin')
plt.legend(loc='center')
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
